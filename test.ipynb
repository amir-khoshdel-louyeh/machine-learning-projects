# %%
import numpy as np

# %%
e = np.arange(0, 10, 2)
e
# Out:
# array([0, 2, 4, 6, 8])

# %%
f = np.linspace(0, 1, 5)
f
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
g = np.random.rand(3, 2)
g
# Out:
# array([[0.71896657, 0.7219228 ],
#        [0.85062181, 0.70472943],
#        [0.97878207, 0.15301824]])
